# %%
from toidisplay import load_metadata

# %%
metadata = load_metadata()
# Out:
# Loading metadata...
# done

# %%
metadata
# Out:
#              pub_date   txt_zip                                   txt_file  \
# record_id
# 231555216  1913-03-12  1913.zip           231555216services_commission.txt
# 230994693  1900-06-20  1900.zip          230994693the_tilati_collision.txt
# 231284150  1910-12-28  1910.zip     231284150classified_ad_5__no_title.txt
# 231149410  1880-11-01  1880.zip         231149410bombay_army_sta_lions.txt
# 231263612  1880-11-25  1880.zip           231263612article_9__no_title.txt
# ...               ...       ...                                        ...
# 741182338  1973-07-20  1973.zip  741182338state_athletic_body_in_a_fix.txt
# 739222642  1975-12-24  1975.zip                  739222642cooler_night.txt
# 617140604  1992-12-27  1992.zip           617140604asian_lady_triumphs.txt
# 614109113  1992-02-15  1992.zip       614109113display_ad_52__no_title.txt
# 738342475  1926-08-23  1926.zip     738342475study_of_indian_phiosophy.txt
#
# ...
